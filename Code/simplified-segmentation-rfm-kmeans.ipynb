# %% [markdown]
# ![1-min.png](attachment:f1e02ad8-a48c-42a0-8637-0fa4e3d6e2f2.png)

# %% [markdown]
# ![2-min.png](attachment:5c3c9daa-233c-4983-a953-64899a9fc2f5.png)

# %% [markdown]
# ![3-min.png](attachment:ee4fb9c3-0efc-4515-b8f8-c5eba02e471c.png)

# %% [markdown]
# ![5-min.png](attachment:63bd0463-2b52-4c8f-8ba1-91176efb7e74.png)
#
# [Click here to visit the site](https://thecleverprogrammer.com/2021/02/08/customer-personality-analysis-with-python/)

# %% [markdown]
# ![6-min.png](attachment:f86886ad-1f3c-4765-805d-ac146664e399.png)

# %% [markdown]
# > **Importing necessary libaries**

# %%
# Core Libraries.
import pandas as pd
import numpy as np
import warnings
import datetime as dt

#Visualization
import matplotlib.pyplot as plt
import seaborn as sns
from yellowbrick.cluster import KElbowVisualizer
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

#Precison Handling settings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', 160)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
#Reading data set
data_og = pd.read_csv("/kaggle/input/customer-personality-analysis/marketing_campaign.csv", sep="\t")
data_og.head(3)
# Out:
#      ID  Year_Birth   Education Marital_Status    Income  Kidhome  Teenhome Dt_Customer  Recency  MntWines  MntFruits  MntMeatProducts  MntFishProducts  \
# 0  5524        1957  Graduation         Single 58138.000        0         0  04-09-2012       58       635         88              546              172
# 1  2174        1954  Graduation         Single 46344.000        1         1  08-03-2014       38        11          1                6                2
# 2  4141        1965  Graduation       Together 71613.000        0         0  21-08-2013       26       426         49              127              111
#
#    MntSweetProducts  MntGoldProds  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  NumStorePurchases  NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  \
# 0                88            88                  3                8                   10                  4                  7             0             0
# 1                 1             6                  2                1                    1                  2                  5             0             0
# 2                21            42                  1                8                    2                 10                  4             0             0
#
#    AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  Complain  Z_CostContact  Z_Revenue  Response
# 0             0             0             0         0              3         11         1
# 1             0             0             0         0              3         11         0
# 2             0             0             0         0              3         11         0

# %%
data = data_og[["ID","Recency","MntWines","MntFruits","MntMeatProducts","MntFishProducts","MntSweetProducts","MntGoldProds","NumDealsPurchases","NumWebPurchases","NumCatalogPurchases","NumStorePurchases","Kidhome","Teenhome"]]
data.head(3)
# Out:
#      ID  Recency  MntWines  MntFruits  MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  NumDealsPurchases  NumWebPurchases  \
# 0  5524       58       635         88              546              172                88            88                  3                8
# 1  2174       38        11          1                6                2                 1             6                  2                1
# 2  4141       26       426         49              127              111                21            42                  1                8
#
#    NumCatalogPurchases  NumStorePurchases  Kidhome  Teenhome
# 0                   10                  4        0         0
# 1                    1                  2        1         1
# 2                    2                 10        0         0

# %%
#Exploring data frame, identifying Potential Errors and understanding the datatypes
pd.set_option('display.max_columns', None) 
def data_overview(df, head=5):
    print(" SHAPE ".center(125,'-'))
    print('Rows:{}'.format(df.shape[0]))
    print('Columns:{}'.format(df.shape[1]))
    print(" HEAD ".center(125,'-'))
    print(df.head(head))
    print(" MISSING VALUES ".center(125,'-'))
    print(df.isnull().sum())
    print(" DUPLICATED VALUES ".center(125,'-'))
    print(df.duplicated().sum())
    
data_overview(data)
# Out:
# ----------------------------------------------------------- SHAPE -----------------------------------------------------------
# Rows:2240
# Columns:14
# ------------------------------------------------------------ HEAD -----------------------------------------------------------
#      ID  Recency  MntWines  MntFruits  MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  NumDealsPurchases  NumWebPurchases  \
# 0  5524       58       635         88              546              172                88            88                  3                8
# 1  2174       38        11          1                6                2                 1             6                  2                1
# 2  4141       26       426         49              127              111                21            42                  1                8
# 3  6182       26        11          4               20               10                 3             5                  2                2
# 4  5324       94       173         43              118               46                27            15                  5                5
#
#    NumCatalogPurchases  NumStorePurchases  Kidhome  Teenhome
# 0                   10                  4        0         0
# 1                    1                  2        1         1
# 2                    2                 10        0         0
# 3                    0                  4        1         0
# 4                    3                  6        1         0
# ------------------------------------------------------- MISSING VALUES ------------------------------------------------------
# ID                     0
# Recency                0
# MntWines               0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# Kidhome                0
# Teenhome               0
# dtype: int64
# ----------------------------------------------------- DUPLICATED VALUES -----------------------------------------------------
# 0

# %%
#Feature indicating total children living in the household
data["Children"]=data["Kidhome"]+data["Teenhome"]
#Feature pertaining parenthood
data["Is_Parent"] = np.where(data.Children> 0, 1, 0)
#extracting only necessary attributes for modelling
data=data.rename(columns={"MntWines": "Wines","MntFruits":"Fruits","MntMeatProducts":"Meat","MntFishProducts":"Fish","MntSweetProducts":"Sweets","MntGoldProds":"Gold"})
data.head()
# Out:
#      ID  Recency  Wines  Fruits  Meat  Fish  Sweets  Gold  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  NumStorePurchases  Kidhome  Teenhome  \
# 0  5524       58    635      88   546   172      88    88                  3                8                   10                  4        0         0
# 1  2174       38     11       1     6     2       1     6                  2                1                    1                  2        1         1
# 2  4141       26    426      49   127   111      21    42                  1                8                    2                 10        0         0
# 3  6182       26     11       4    20    10       3     5                  2                2                    0                  4        1         0
# 4  5324       94    173      43   118    46      27    15                  5                5                    3                  6        1         0
#
#    Children  Is_Parent
# 0         0          0
# 1         2          1
# 2         0          0
# 3         1          1
# 4         1          1

# %% [markdown]
# ![7-min.png](attachment:dd4015c0-ec43-4ba9-87db-d08fd71045f3.png)

# %% [markdown]
# > **Featuring Frequency and Monatery**

# %%
# Frequency measures the purchase frequency within a specified period.
data["Frequency"] = data["NumDealsPurchases"] + data["NumWebPurchases"] + data["NumCatalogPurchases"] + data["NumStorePurchases"]
# Monetary measures the total monetary expenditure within a specified period.
data["Monatery"] = data["Wines"]+data["Fruits"]+ data["Meat"]+ data["Fish"]+ data["Sweets"]+ data["Gold"] #Total amt spent

# %%
data.head(3)
# Out:
#      ID  Recency  Wines  Fruits  Meat  Fish  Sweets  Gold  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  NumStorePurchases  Kidhome  Teenhome  \
# 0  5524       58    635      88   546   172      88    88                  3                8                   10                  4        0         0
# 1  2174       38     11       1     6     2       1     6                  2                1                    1                  2        1         1
# 2  4141       26    426      49   127   111      21    42                  1                8                    2                 10        0         0
#
#    Children  Is_Parent  Frequency  Monatery
# 0         0          0         25      1617
# 1         2          1          6        27
# 2         0          0         21       776

# %%
#lets check for outliers.
print("Reletive Plot Of Some Selected Features: A Data Subset")
plt.figure()
sns.pairplot(data[[ "Recency","Frequency","Monatery", "Is_Parent"]], hue= "Is_Parent",palette= "bright")
# Out:
# Reletive Plot Of Some Selected Features: A Data Subset

# %% [markdown]
# Data frame looks good without any discrepancy.

# %%
rfm = data[["Recency","Frequency","Monatery"]] 
rfm.head()
# Out:
#    Recency  Frequency  Monatery
# 0       58         25      1617
# 1       38          6        27
# 2       26         21       776
# 3       26          8        53
# 4       94         19       422

# %%
#scaling data 
scaler = StandardScaler()
rfm_scaled = scaler.fit_transform(rfm)
rfm_scaled = pd.DataFrame(rfm_scaled)
#Renaming the columns
rfm_scaled.columns = ["recency","frequency","monatery"]
rfm_scaled.head()
# Out:
#    recency  frequency  monatery
# 0    0.307      1.321     1.679
# 1   -0.384     -1.155    -0.961
# 2   -0.798      0.800     0.283
# 3   -0.798     -0.894    -0.918
# 4    1.550      0.539    -0.305

# %% [markdown]
# ![8-min.png](attachment:fdb032c4-11dc-49d7-8908-78895c33cc79.png)

# %% [markdown]
# > **We need to find optimal value of K for modeling i.e., number of groups to be obtined. It can be acheived by Elbow method.**

# %%
# Random initailazing of k=10 to plot graph and find Elbow
plt.figure(figsize=(10,5))
Elbow_M = KElbowVisualizer(KMeans(), k=10) 
Elbow_M.fit(rfm_scaled)
Elbow_M.show()
# Out:
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %% [markdown]
# > Therefore K = 4

# %%
#KMeans Clustering
kmeans = KMeans(n_clusters=4,max_iter=50)
kmeans.fit(rfm_scaled)
# Out:
# KMeans(max_iter=50, n_clusters=4)

# %%
rfm_scaled["clusters"]=kmeans.labels_
rfm["clusters"]=kmeans.labels_
data["clusters"] = kmeans.labels_
rfm_scaled.head()
# Out:
#    recency  frequency  monatery  clusters
# 0    0.307      1.321     1.679         2
# 1   -0.384     -1.155    -0.961         0
# 2   -0.798      0.800     0.283         1
# 3   -0.798     -0.894    -0.918         0
# 4    1.550      0.539    -0.305         2

# %%
#centriods
kmeans.cluster_centers_
# Out:
# array([[-0.8507059 , -0.79285744, -0.78354681],
#        [-0.89884278,  0.92997001,  0.88866276],
#        [ 0.82663662,  0.86245849,  0.89270189],
#        [ 0.88544385, -0.77676837, -0.77989179]])

# %%
# grouping the data in accorandance with each cluster seperately
one = rfm_scaled[rfm_scaled["clusters"]==0]
two = rfm_scaled[rfm_scaled["clusters"]==1]
three = rfm_scaled[rfm_scaled["clusters"]==2]
four = rfm_scaled[rfm_scaled["clusters"]==3]

#Lets check the quality of clustering in the data set
plt.figure(figsize=(5,5))
plt.scatter(one["recency"],one["frequency"],color='green')
plt.scatter(two["recency"],two["frequency"],color='red')
plt.scatter(three["recency"],three["frequency"],color='grey')
plt.scatter(four["recency"],four["frequency"],color='blue')
plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],color="black",marker="*",label="centroid")
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# > Data had been homogeneously divided and grouped w.r.t its nearest centroid.

# %% [markdown]
# ![9-min.png](attachment:ace216e2-f198-4060-9029-d1e3d5cf39c1.png)

# %%
# Lets see the recency of each clusters
sns.set(rc={"figure.figsize":(8, 4)})
sns.boxplot(x="clusters",y="recency",data=rfm_scaled).set_title("Recency v/s Clusters")
# Out:
# Text(0.5, 1.0, 'Recency v/s Clusters')

# %%
# Lets see the frequency of each clusters
sns.boxplot(x="clusters",y="frequency",data=rfm_scaled).set_title("Frequency v/s Clusters")
# Out:
# Text(0.5, 1.0, 'Frequency v/s Clusters')

# %%
# Lets see the monatery of each clusters
sns.boxplot(x="clusters",y="monatery",data=rfm_scaled).set_title("Monatery v/s Clusters")
# Out:
# Text(0.5, 1.0, 'Monatery v/s Clusters')

# %% [markdown]
# ![10-min.png](attachment:3d91429e-adc1-4089-ba61-5a26cd4e16a8.png)

# %% [markdown]
# **Score Desicion table:**
#
# ![11-min.png](attachment:2b45dc3a-d560-4339-9768-19d0f68e27fe.png)

# %%
# Lets create bins and assign scores for rfm value
bins1 = np.linspace(rfm["Recency"].min(),rfm["Recency"].max(),6)
rfm["r_score"] = pd.cut(rfm["Recency"],bins1,labels=[5,4,3,2,1],include_lowest=True)

bins2 = np.linspace(rfm["Frequency"].min(),rfm["Frequency"].max(),6)
rfm["f_score"] = pd.cut(rfm["Frequency"],bins2,labels=[1,2,3,4,5],include_lowest=True)

bins3 = np.linspace(rfm["Monatery"].min(),rfm["Monatery"].max(),6)
rfm["m_score"] = pd.cut(rfm["Monatery"],bins3,labels=[1,2,3,4,5],include_lowest=True)

rfm["RFM SCORE"] = rfm["r_score"].astype(str) + rfm["f_score"].astype(str)
rfm.head()
# Out:
#    Recency  Frequency  Monatery  clusters r_score f_score m_score RFM SCORE
# 0       58         25      1617         2       3       3       4        33
# 1       38          6        27         0       4       1       1        41
# 2       26         21       776         1       4       3       2        43
# 3       26          8        53         0       4       1       1        41
# 4       94         19       422         2       1       3       1        13

# %%
# creating dictionary to name each segments
dict_seg = {
    r'[1-2][1-2]': 'hibernating',
    r'[1-2][3-4]': 'at_Risk',
    r'[1-2]5': 'cant_loose',
    r'3[1-2]': 'about_to_sleep',
    r'33': 'need_attention',
    r'[3-4][4-5]': 'loyal_customers',
    r'41': 'promising',
    r'51': 'new_customers',
    r'[4-5][2-3]': 'potential_loyalists',
    r'5[4-5]': 'champions'
}

rfm['segment'] = rfm['RFM SCORE'].replace(dict_seg, regex = True)
data['segment'] = rfm['RFM SCORE'].replace(dict_seg, regex = True) 
data.head()
# Out:
#      ID  Recency  Wines  Fruits  Meat  Fish  Sweets  Gold  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  NumStorePurchases  Kidhome  Teenhome  \
# 0  5524       58    635      88   546   172      88    88                  3                8                   10                  4        0         0
# 1  2174       38     11       1     6     2       1     6                  2                1                    1                  2        1         1
# 2  4141       26    426      49   127   111      21    42                  1                8                    2                 10        0         0
# 3  6182       26     11       4    20    10       3     5                  2                2                    0                  4        1         0
# 4  5324       94    173      43   118    46      27    15                  5                5                    3                  6        1         0
#
#    Children  Is_Parent  Frequency  Monatery  clusters              segment
# 0         0          0         25      1617         2       need_attention
# 1         2          1          6        27         0            promising
# 2         0          0         21       776         1  potential_loyalists
# 3         1          1          8        53         0            promising
# 4         1          1         19       422         2              at_Risk

# %%
#lets segregate dataframe w.r.t its cluster
c1 = data[data["clusters"]==0]
c2 =data[data["clusters"]==1]
c3 = data[data["clusters"]==2]
c4 = data[data["clusters"]==3]

# %%
#Lets check who all are there in each clusters
sns.set(rc={"figure.figsize":(20, 4)})
fig, ax =plt.subplots(1,2)
sns.countplot(x="segment",data=c1,ax=ax[0]).set_title("Cluster 1")
sns.countplot(x="segment",data=c2,ax=ax[1]).set_title("Cluster 2")
fig.show()

# %%
sns.set(rc={"figure.figsize":(20, 4)})
fig, ax =plt.subplots(1,2)
sns.countplot(x="segment",data=c3,ax=ax[0]).set_title("Cluster 3")
sns.countplot(x="segment",data=c4,ax=ax[1]).set_title("Cluster 4")
fig.show()

# %% [markdown]
# **Description of segment title:**
#
# ![12-min.png](attachment:70828aca-3f08-4fb6-b144-effb01302676.png)

# %% [markdown]
# ![13-min.png](attachment:2d2c0715-23cd-4e0b-97d9-151cfd084869.png)

# %% [markdown]
# ![14-min.png](attachment:c78023f5-a342-4009-8d47-2ac98a5d1440.png)

# %% [markdown]
# ![4-min.png](attachment:fbf27776-3a3d-42ce-9889-58a476aa5968.png)

# %% [markdown]
# REFERENCE:
#     [1] Ina Maryani 1, Dwiza Riana 2, Rachmawati Darma Astuti, 2021, "Customer Segmentation based on RFM model and Clustering Techniques With K-Means Algorithm",4-5.
#     [2] Divya Chandana,2023, "Exploring Customers Segmentation With RFMAnalysis and K-Means Clustering", 1-7.
#     [3] https://scikit-learn.org/.
