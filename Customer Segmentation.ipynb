# %% [markdown]
# # Importing The Libraries

# %%
import import_ipynb
from function import *
# Out:
# importing Jupyter notebook from function.ipynb

# %% [markdown]
# # Loading and Reading the Dataset

# %%
df = pd.read_csv(r"C:\Users\HP\OneDrive - National Economics University\Study NEU\DBA\Project 2\Dataset\archive (1)\marketing_campaign.csv", sep='\t')
df.head()
# Out:
#      ID  Year_Birth   Education Marital_Status    Income  Kidhome  Teenhome Dt_Customer  Recency  MntWines  MntFruits  MntMeatProducts  MntFishProducts  \
# 0  5524        1957  Graduation         Single 58138.000        0         0  04-09-2012       58       635         88              546              172
# 1  2174        1954  Graduation         Single 46344.000        1         1  08-03-2014       38        11          1                6                2
# 2  4141        1965  Graduation       Together 71613.000        0         0  21-08-2013       26       426         49              127              111
# 3  6182        1984  Graduation       Together 26646.000        1         0  10-02-2014       26        11          4               20               10
# 4  5324        1981         PhD        Married 58293.000        1         0  19-01-2014       94       173         43              118               46
#
# ...

# %% [markdown]
# # Exploring Information of the Dataset

# %%
data_overview1(df, head=5)
# Out:
# ------------------------------------------------------ SHAPE OF DATASET -----------------------------------------------------
# Rows: 2240
# Columns: 29
# Shape of Dataset: (2240, 29)
# ----------------------------------------------------------DATA TYPES---------------------------------------------------------
# int64      25
# object      3
# float64     1
# Name: count, dtype: int64
# ------------------------------------------------------- MISSING VALUES ------------------------------------------------------
# Income    24
# dtype: int64
# ----------------------------------------------------- DUPLICATED VALUES -----------------------------------------------------
# 0
# ----------------------------------------------------------DATA INFO----------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ...

# %%
print(" STATISTICS OF DATA ".center(125,'-'))
df.describe(include="all")
# Out:
# ----------------------------------------------------- STATISTICS OF DATA ----------------------------------------------------
#               ID  Year_Birth   Education Marital_Status     Income  Kidhome  Teenhome Dt_Customer  Recency  MntWines  MntFruits  MntMeatProducts  \
# count   2240.000    2240.000        2240           2240   2216.000 2240.000  2240.000        2240 2240.000  2240.000   2240.000         2240.000
# unique       NaN         NaN           5              8        NaN      NaN       NaN         663      NaN       NaN        NaN              NaN
# top          NaN         NaN  Graduation        Married        NaN      NaN       NaN  31-08-2012      NaN       NaN        NaN              NaN
# freq         NaN         NaN        1127            864        NaN      NaN       NaN          12      NaN       NaN        NaN              NaN
# ...

# %% [markdown]
# - The Dataset has 2240 rows and 29 columns
# - The Dataset has 3 types of columns: strings(3), integer(25), float(1)
# - The Dataset has Missing values in Income (24)

# %%
df.columns
# Out:
# Index(['ID', 'Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome', 'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases', 'NumCatalogPurchases',
#        'NumStorePurchases', 'NumWebVisitsMonth', 'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1', 'AcceptedCmp2', 'Complain', 'Z_CostContact',
#        'Z_Revenue', 'Response'],
#       dtype='object')

# %% [markdown]
# # Data Wrangling

# %%
columns_to_drop = ['Year_Birth', 'Education', 'Marital_Status', 'Income', 'Dt_Customer', 'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1', 'AcceptedCmp2', 'Complain', 'Z_CostContact', 'Z_Revenue', 'Response', 'NumWebVisitsMonth']

# Drop unnecessary columns
df = df.drop(columns=columns_to_drop)

# %%
df.shape
# Out:
# (2240, 14)

# %%
df.columns
# Out:
# Index(['ID', 'Kidhome', 'Teenhome', 'Recency', 'MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds',
#        'NumDealsPurchases', 'NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases'],
#       dtype='object')

# %%
df = df[["ID","Recency","MntWines","MntFruits","MntMeatProducts","MntFishProducts","MntSweetProducts","MntGoldProds","NumDealsPurchases","NumWebPurchases","NumCatalogPurchases","NumStorePurchases","Kidhome","Teenhome"]]
df.head(3)
# Out:
#      ID  Recency  MntWines  MntFruits  MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  NumDealsPurchases  NumWebPurchases  \
# 0  5524       58       635         88              546              172                88            88                  3                8
# 1  2174       38        11          1                6                2                 1             6                  2                1
# 2  4141       26       426         49              127              111                21            42                  1                8
#
#    NumCatalogPurchases  NumStorePurchases  Kidhome  Teenhome
# 0                   10                  4        0         0
# 1                    1                  2        1         1
# 2                    2                 10        0         0

# %%
data_overview1(df, head=5)
# Out:
# ------------------------------------------------------ SHAPE OF DATASET -----------------------------------------------------
# Rows: 2240
# Columns: 14
# Shape of Dataset: (2240, 14)
# ----------------------------------------------------------DATA TYPES---------------------------------------------------------
# int64    14
# Name: count, dtype: int64
# ------------------------------------------------------- MISSING VALUES ------------------------------------------------------
# Series([], dtype: int64)
# ----------------------------------------------------- DUPLICATED VALUES -----------------------------------------------------
# 0
# ----------------------------------------------------------DATA INFO----------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
# ...

# %%
df.head()
# Out:
#      ID  Recency  MntWines  MntFruits  MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  NumDealsPurchases  NumWebPurchases  \
# 0  5524       58       635         88              546              172                88            88                  3                8
# 1  2174       38        11          1                6                2                 1             6                  2                1
# 2  4141       26       426         49              127              111                21            42                  1                8
# 3  6182       26        11          4               20               10                 3             5                  2                2
# 4  5324       94       173         43              118               46                27            15                  5                5
#
#    NumCatalogPurchases  NumStorePurchases  Kidhome  Teenhome
# 0                   10                  4        0         0
# ...

# %%
#Feature indicating total children living in the household

df["Children"] = df["Kidhome"] + df["Teenhome"]

# %%
#Feature pertaining parenthood

df["Is_Parent"] = np.where(df.Children > 0, 1, 0)

# %%
#extracting only necessary attributes for modelling

df = df.rename(columns={"MntWines": "Wines","MntFruits":"Fruits","MntMeatProducts":"Meat","MntFishProducts":"Fish","MntSweetProducts":"Sweets","MntGoldProds":"Gold"})
df.head()
# Out:
#      ID  Recency  Wines  Fruits  Meat  Fish  Sweets  Gold  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  NumStorePurchases  Kidhome  Teenhome  \
# 0  5524       58    635      88   546   172      88    88                  3                8                   10                  4        0         0
# 1  2174       38     11       1     6     2       1     6                  2                1                    1                  2        1         1
# 2  4141       26    426      49   127   111      21    42                  1                8                    2                 10        0         0
# 3  6182       26     11       4    20    10       3     5                  2                2                    0                  4        1         0
# 4  5324       94    173      43   118    46      27    15                  5                5                    3                  6        1         0
#
#    Children  Is_Parent
# 0         0          0
# ...

# %%
# Frequency measures the purchase frequency within a specified period.

df["Frequency"] = df["NumDealsPurchases"] + df["NumWebPurchases"] + df["NumCatalogPurchases"] + df["NumStorePurchases"]

# %%
# Monetary measures the total monetary expenditure within a specified period.

df["Monetary"] = df["Wines"] + df["Fruits"] + df["Meat"] + df["Fish"] + df["Sweets"] + df["Gold"] #Total amt spent

# %%
df.head(3)
# Out:
#      ID  Recency  Wines  Fruits  Meat  Fish  Sweets  Gold  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  NumStorePurchases  Kidhome  Teenhome  \
# 0  5524       58    635      88   546   172      88    88                  3                8                   10                  4        0         0
# 1  2174       38     11       1     6     2       1     6                  2                1                    1                  2        1         1
# 2  4141       26    426      49   127   111      21    42                  1                8                    2                 10        0         0
#
#    Children  Is_Parent  Frequency  Monetary
# 0         0          0         25      1617
# 1         2          1          6        27
# 2         0          0         21       776

# %%
f, ax = plt.subplots(4,1, figsize = (20,5))
col_list = ["Recency","Frequency","Monetary", "Is_Parent"]
for i in range(0,4):
    ax[i].boxplot(df[col_list[i]],flierprops = dict(marker = "s", markerfacecolor = "red"), vert = 0)
plt.show()

# %% [markdown]
# Dataframe looks good without any discrepancy.

# %% [markdown]
# # Feature Engineering

# %%
rfm = df[["Recency","Frequency","Monetary"]] 
rfm.head()
# Out:
#    Recency  Frequency  Monetary
# 0       58         25      1617
# 1       38          6        27
# 2       26         21       776
# 3       26          8        53
# 4       94         19       422

# %%
#scaling data 
scaler = StandardScaler()
rfm_scaled = scaler.fit_transform(rfm)
rfm_scaled = pd.DataFrame(rfm_scaled)

# %%
rfm_scaled.columns = ["Recency","Frequency","Monetary"]
rfm_scaled.head()
# Out:
#    Recency  Frequency  Monetary
# 0    0.307      1.321     1.679
# 1   -0.384     -1.155    -0.961
# 2   -0.798      0.800     0.283
# 3   -0.798     -0.894    -0.918
# 4    1.550      0.539    -0.305

# %% [markdown]
# # Modelling

# %%
# Random initailazing of k=10 to plot graph and find Elbow

plt.figure(figsize=(10,5))
Elbow_M = KElbowVisualizer(KMeans(), k=10) 
Elbow_M.fit(rfm_scaled)
Elbow_M.show()
# Out:
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %% [markdown]
# **Therefore K=4**

# %%
compute_silhouette_scores(rfm)
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.6913543225712762
# For n_clusters = 3 The average silhouette_score is : 0.6617482811141504
# For n_clusters = 4 The average silhouette_score is : 0.6314914074060318
# For n_clusters = 5 The average silhouette_score is : 0.617267714899686

# %%
#KMeans Clustering

kmeans = KMeans(n_clusters=4,max_iter=50)
kmeans.fit(rfm_scaled)
# Out:
# KMeans(max_iter=50, n_clusters=4)

# %%
rfm_scaled["Clusters"]=kmeans.labels_
rfm["Clusters"]=kmeans.labels_
df["Clusters"] = kmeans.labels_
rfm_scaled.head()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14648\3299794364.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rfm["Clusters"]=kmeans.labels_
#    Recency  Frequency  Monetary  Clusters
# 0    0.307      1.321     1.679         0
# 1   -0.384     -1.155    -0.961         1
# 2   -0.798      0.800     0.283         3
# 3   -0.798     -0.894    -0.918         1
# 4    1.550      0.539    -0.305         0

# %%
#centriods

kmeans.cluster_centers_
# Out:
# array([[ 0.82456268,  0.86554056,  0.89989556],
#        [-0.84699213, -0.80959685, -0.79267291],
#        [ 0.89002869, -0.7680078 , -0.77604328],
#        [-0.89901939,  0.91937139,  0.87084815]])

# %%
# grouping the data in accorandance with each cluster seperately
one = rfm_scaled[rfm_scaled["Clusters"]==0]
two = rfm_scaled[rfm_scaled["Clusters"]==1]
three = rfm_scaled[rfm_scaled["Clusters"]==2]
four = rfm_scaled[rfm_scaled["Clusters"]==3]

# %%
#Checking the quality of clustering in the data set

plot_clusters(one, two, three, four, kmeans)

# %%
lists = ['Recency', 'Frequency', 'Monetary']

plot_metrics_vs_clusters(rfm_scaled, lists)

# %% [markdown]
# ### Silhouette Coefficient (silhouette score)

# %%
print_silhouette_scores(rfm_scaled, kmeans.labels_, metrics)
# Out:
# Silhouette score with euclidean metric: 0.5478139730044117
# Silhouette score with manhattan metric: 0.6111154391168484
# Silhouette score with cosine metric: 0.6953056134310535
# Silhouette score with chebyshev metric: 0.4884308447741699
# Silhouette score with minkowski metric: 0.5478139730046665
# Silhouette score with sqeuclidean metric: 0.7519754491701117
# Silhouette score with seuclidean metric: 0.5362088393734816
# Silhouette score with mahalanobis metric: 0.4553643858332535
# Silhouette score with correlation metric: 0.44190336211209413

# %% [markdown]
# # Segment Visualization

# %%
# Lets create bins and assign scores for rfm value
bins1 = np.linspace(rfm["Recency"].min(), rfm["Recency"].max(),6)
rfm["r_score"] = pd.cut(rfm["Recency"],bins1,labels=[5,4,3,2,1],include_lowest=True)

bins2 = np.linspace(rfm["Frequency"].min(),rfm["Frequency"].max(),6)
rfm["f_score"] = pd.cut(rfm["Frequency"],bins2,labels=[1,2,3,4,5],include_lowest=True)

bins3 = np.linspace(rfm["Monetary"].min(),rfm["Monetary"].max(),6)
rfm["m_score"] = pd.cut(rfm["Monetary"],bins3,labels=[1,2,3,4,5],include_lowest=True)

rfm["RFM SCORE"] = rfm["r_score"].astype(str) + rfm["f_score"].astype(str)
rfm.head()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14648\1298183649.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rfm["r_score"] = pd.cut(rfm["Recency"],bins1,labels=[5,4,3,2,1],include_lowest=True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_14648\1298183649.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rfm["f_score"] = pd.cut(rfm["Frequency"],bins2,labels=[1,2,3,4,5],include_lowest=True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_14648\1298183649.py:9: SettingWithCopyWarning:
# ...

# %%
# creating dictionary to name each segments
dict_seg = {
    r'[1-2][1-2]': 'hibernating',
    r'[1-2][3-4]': 'at_Risk',
    r'[1-2]5': 'cant_loose',
    r'3[1-2]': 'about_to_sleep',
    r'33': 'need_attention',
    r'[3-4][4-5]': 'loyal_customers',
    r'41': 'promising',
    r'51': 'new_customers',
    r'[4-5][2-3]': 'potential_loyalists',
    r'5[4-5]': 'champions'
}

rfm['Segment'] = rfm['RFM SCORE'].replace(dict_seg, regex = True)
df['Segment'] = rfm['RFM SCORE'].replace(dict_seg, regex = True) 
df.head()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14648\4072990775.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rfm['Segment'] = rfm['RFM SCORE'].replace(dict_seg, regex = True)
#      ID  Recency  Wines  Fruits  Meat  Fish  Sweets  Gold  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  NumStorePurchases  Kidhome  Teenhome  \
# 0  5524       58    635      88   546   172      88    88                  3                8                   10                  4        0         0
# 1  2174       38     11       1     6     2       1     6                  2                1                    1                  2        1         1
# ...

# %%
c1 = df[df["Clusters"]==0]
c2 =df[df["Clusters"]==1]
c3 = df[df["Clusters"]==2]
c4 = df[df["Clusters"]==3]

# %%
clusters = [c1, c2, c3, c4]
titles = ["Cluster 1", "Cluster 2", "Cluster 3", "Cluster 4"]
plot_segment_counts(clusters, titles)
# Out:
# <string>:8: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
# <string>:8: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
